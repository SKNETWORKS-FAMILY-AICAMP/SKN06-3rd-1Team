# %% [markdown]
# # **RAG evaluation**
# > - RAG 시스템의 정보 검색 능력과 답변 생성 능력을 측정
#
# > - **평가 지표 (값이 1에 가까울 수록 성능이 좋음)**
# > - **LLMContextRecall**: 컨텍스트를 기반으로 정보를 재현한 능력을 측정
# > - **LLMContextPrecisionWithReference**: 문서의 정확하고 관련된 정보를 기반으로 답변을 생성했는지 평가
# > - **Faithfulness**: 문서의 내용에 얼마나 충실하게 답변했는지 평가
# > - **AnswerRelevancy**: 질문과 답변 간의 의미적 관련성을 측정

# %%
from langchain_chroma import Chroma

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.prompts import PromptTemplate, MessagesPlaceholder, ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser,StrOutputParser

from langchain_core.runnables import RunnableLambda
from langchain_core.documents import Document
from langchain_community.tools import TavilySearchResults
from langchain_core.runnables.history import RunnableWithMessageHistory, RunnableLambda

from ragas import EvaluationDataset, RunConfig, evaluate
from ragas.metrics import (
    LLMContextRecall, Faithfulness, LLMContextPrecisionWithReference, AnswerRelevancy
)
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper

from pydantic import BaseModel, Field

from textwrap import dedent
from operator import itemgetter
from pprint import pprint
import json
import random
import re

from langchain_core.tools import tool
from itertools import chain

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # **질문-답변 생성**
#
# - 평가 데이터로 사용할 context 100개를 랜덤으로 추출한 뒤, 각 3개씩의 질문-답변 쌍을 생성하여 **총 300개의 질문-답변 쌍**을 생성함
# - 생성된 데이터는 csv 파일 형태로 저장

# %%
# 데이터 파일 경로
DOC_PATH = 'policy_result.json'

# 파일 로딩
with open(DOC_PATH, 'r', encoding='utf-8') as file:
    json_data = json.load(file)

# 문서 리스트 생성 (각 정책 항목을 문자열로 변환)
docs = []
for policy_name, details in json_data.items():
    # 정책 이름과 상세 내용을 문자열로 합침
    policy_content = f"정책 이름: {policy_name}\n"
    for detail in details:
        policy_content += f"{detail}\n"
    docs.append(policy_content.strip())

# docs 내용 확인
len(docs), docs[:1]  # 문서 개수와 첫 번째 문서 내용 출력
# Out:
# (1268,
#  ['정책 이름: 청년 주택드림 청약통장\n기관:국토교통부\n정책 분야:주거분야\n지원 내용:  이율  최대 4.5    소득   5 000만원 직전년도 신고소득이      무주택   납입한도  월 100만원   납입금액의 40 까지 소득공제   주택청약에 당첨된  청년주택드림 대출 계   청년주택드림 청약통장 1년 이상 가입   1 000만원 이상 납입   당첨  분양가 80 까지 대출   금리 최저  2.2  만기  소득별 차  최장 40년까지 지원 고정금리    6억 이하  전용면적 85제곱미터 이하 주택   생애주기별 금리 인하  결혼 0.1 p 인하  출산  0.5 p 인하  다녀  0.2 p 인하\n사업 신청 기간:2024년 02월21일   2024년 12월31일\n비고: 기존 청년우대형통장 가입는 출일에 맞춰서 동 전환 일반청약 가입는 요건에만 맞으면 전환 가입 \n연령:만 19세   34세\n거주지 및 소득:  청년 주택드림 청약통장 소득    5 000만원 이하\n기타 유익 정보:  업무 취급 은행   우리은행   1599 0800   KB 국민은행   1599 1771   IBK 기업은행   1566 2566   NHBank   1588 2100   신한은행   1599 8000   하나은행   1599 1111   대구은행   1566 5050   부산은행   1800 1333   경남은행   1600 8585\n주관 기관:국토교통부\n운영 기관:국토교통부'])

# %%
### 평가 데이터로 사용할 context 추출
total_samples = 100

# index shuffle 후 total_samples만큼 context 추출
idx_list = list(range(len(docs)))
random.shuffle(idx_list)

eval_context_list = []
while len(eval_context_list) < total_samples:
    idx = idx_list.pop()
    context = docs[idx]
    if len(context) > 50: # 50글자 이상인 text만 사용
        eval_context_list.append(context)

len(eval_context_list)

# %%
# user_input: 질문
# ####### retrieved_contexts: 검색된 문서의 내용(page_content)들
# qa_context: 질문 답변 쌍을 만들 때 참고한 context
        # retrieved_contexts: 검색된 문서의 내용은 실제 RAG 실행시 넣는다.
        # response: 모델의 답변 - 실제 RAG 실행시 넣는다.
# reference: 정답

#######################################################################################################################################

class EvalDatasetSchema(BaseModel):
    user_input: str = Field(..., title="질문(question)")
    qa_context: list[str] = Field(..., title="질문-답변 쌍을 만들 때 참조한 context.")
    reference: str = Field(..., title="질문의 정답(ground truth)")

parser = JsonOutputParser(pydantic_object=EvalDatasetSchema)

eval_model = ChatOpenAI(model="gpt-4o")

prompt_template = PromptTemplate.from_template(
    template=dedent("""
        당신은 RAG 평가를 위해 질문과 정답 쌍을 생성하는 인공지능 비서입니다.
        해당 RAG는 사용자에게 각 정책에 대한 질의응답을 위해 만들어졌으니 이를 참고하여 평가 질문과 정답 쌍을 생성하세요.
        주어진 [Context]를 활용해서 최대한 다양한 질문-정답 쌍을 만들어 주세요.
        다음 [Context] 에 문서가 주어지면 해당 문서를 기반으로 {num_questions}개 질문-정답 쌍을 생성하세요.

        질문과 정답을 생성한 후 아래의 출력 형식 GUIDE 에 맞게 생성합니다.
        질문은 반드시 [Context] 문서에 있는 정보를 바탕으로 생성해야 합니다. [Context]에 없는 내용을 가지고 질문-정답을 절대 만들면 안됩니다.
        질문은 간결하게 작성합니다.

        질문을 만들 때 반드시 각 [Context] 문서의 "정책 이름"을 질문에 포함해야합니다.
        예시는 "경남 저소득 증장애인 집정리 범사업을 주관하는 기관은 어디인가요?" 라는 형식의 질문 생성입니다.

        하나의 질문에는 한 가지의 내용만 작성합니다.
        질문을 만들 때 "제공된 문맥에서", "문서에 설명된 대로", "주어진 문서에 따라" 또는 이와 유사한 말을 하지 마세요.
        정답은 반드시 [Context]에 있는 정보를 바탕으로 작성합니다. 없는 내용을 추가하지 않습니다.
        질문과 정답을 만들고 그 내용이 [Context] 에 있는 항목인지 다시 한번 확인합니다.

        어떤 형식으로 만들었든 생성된 질문-답변 쌍은 반드시 dictionary 형태로 정의하고 list로 묶어서 반환해야 합니다.
        어떤 형식으로 만들었든 질문-답변 쌍은 반드시 {num_questions}개를 만들어야 합니다.

        출력 형식: {format_instructions}

        [Context]
        {context}
        """
    ),
    partial_variables={"format_instructions":parser.get_format_instructions()}
)
# print(prompt_template.template)

eval_dataset_generator = prompt_template | eval_model | parser

# %%
############################################################
# eval_context_list 로 만들기
############################################################
eval_data_list = []
num_questions = 3
for context in eval_context_list:
    _eval_data_list = eval_dataset_generator.invoke({"context":context, "num_questions":num_questions})
    eval_data_list.extend(_eval_data_list)

# %%
import pandas as pd
eval_df = pd.DataFrame(eval_data_list)
eval_df.shape

# %%
## 생성 된 질문/답 쌍 확인
eval_df
# Out:
#                                        user_input  \
# 0    청년 커리어 고민 솔루션 ALL Question 안양의 지원 내용을 알려주세요.
# 1  청년 커리어 고민 솔루션 ALL Question 안양의 신청 절차는 어떻게 되나요?
# 2  청년 커리어 고민 솔루션 ALL Question 안양의 운영 기간은 언제부터인가요?
# 3          경북 영덕군 AIDS 환 의료비 지원 정책의 주관 기관은 어디인가요?
# 4        경북 영덕군 AIDS 환 의료비 지원 정책의 신청 절차는 어떻게 되나요?
# 5          경북 영덕군 AIDS 환 의료비 지원 정책의 운영 기관은 어디인가요?
# 6                    의정부 청년 정신건강상담의 지원 내용은 무엇인가요?
# 7                    의정부 청년 정신건강상담의 주관 기관은 어디인가요?
# 8           의정부 청년 정신건강상담에 신청할 수 있는 연령대는 어떻게 되나요?
#
#                                           qa_context  \
# 0  [정책 이름: 청년 커리어 고민 솔루션  ALL Question   안양, 지원 내...
# 1  [정책 이름: 청년 커리어 고민 솔루션  ALL Question   안양, 신청 절...
# 2  [정책 이름: 청년 커리어 고민 솔루션  ALL Question   안양, 비고: ...
# 3  [정책 이름: 경북 영덕군 AIDS 환 의료비 지원, 기관:경북 영덕군, 정책 분야...
# 4  [정책 이름: 경북 영덕군 AIDS 환 의료비 지원, 기관:경북 영덕군, 정책 분야...
# 5  [정책 이름: 경북 영덕군 AIDS 환 의료비 지원, 기관:경북 영덕군, 정책 분야...
# 6  [정책 이름: 의정부 청년 정신건강상담, 지원 내용: 내용 청년센터에서 진행되는 청...
# 7  [정책 이름: 의정부 청년 정신건강상담, 주관 기관: 의정부 청년센터 031 828...
# 8              [정책 이름: 의정부 청년 정신건강상담, 연령: 만 19세 34세]
#
#                                            reference
# 0  청년의 고민을 현직가가 답해주는 온라인 멘토링을 제공합니다. 진로, 대학, 취업, ...
# 1  16세부터 18세는 안양청년광장 회원가입 후 ALL Q를 이용하고, 19세부터 39...
# 2                            2024년 3월 4일부터 계속 운영됩니다.
# 3                                        영덕군청 감염병관리팀
# 4                                          본인 서식지 작성
# 5                                        영덕군청 감염병관리팀
# 6  청년센터에서 진행되는 청년정신건강상담이며, 청년들의 정신건강문제를 조기 발견하고 상...
# 7                                           의정부 청년센터
# 8                                        만 19세에서 34세

# %%
# csv 파일로 저장
output_path = 'eval_question_sample.csv'    # 저장 경로
eval_df.to_csv(output_path, index=False, encoding='utf-8')

# 저장된 파일 확인
print(f"CSV 파일이 {output_path}에 저장되었습니다.")
# Out:
# CSV 파일이 eval_question_sample.csv에 저장되었습니다.

# %% [markdown]
# # **Chain 구성**
# - Vector Store와 web에서 검색한 context들과 RAG 시스템의 응답이 출력되도록 chain을 구성

# %%
# 저장된 파일을 불러오기
## 앞선 코드에서 이어서 진행 중일 경우 실행하지 않아도 됨.

import pandas as pd

# CSV 파일 경로
csv_file_path = "eval_question.csv"

# CSV 파일 읽기
eval_df = pd.read_csv(csv_file_path)

# 데이터 확인
print(eval_df.head())  # 상위 5개의 데이터 출력
print(eval_df.info())  # 데이터프레임 정보 확인
# Out:
#                                  user_input  \
# 0         울산 동구 지역산업 청년일리 사업의 주관 기관은 어디인가요?
# 1         울산 동구 지역산업 청년일리 사업의 지원 내용은 무엇인가요?
# 2  울산 동구 지역산업 청년일리 사업의 신청 가능한 연령대는 어떻게 되나요?
# 3       청년지원센터 더누림 플랫폼 운영 광주의 주관 기관은 어디인가요?
# 4     청년지원센터 더누림 플랫폼 운영 광주의 신청 절차는 어떻게 되나요?
#
#                                           qa_context  \
# 0  ['정책 이름: 울산 동구 지역산업 청년일리 사업', '주관 기관:울산광역 동구 일...
# 1  ['정책 이름: 울산 동구 지역산업 청년일리 사업', '지원 내용: 추진방법   울...
# 2    ['정책 이름: 울산 동구 지역산업 청년일리 사업', '연령:만 18세   39세']
# 3   ['정책 이름: 청년지원센터 더누림 플랫폼 운영 광주', '주관 기관: 경기도 광주']
# 4  ['정책 이름: 청년지원센터 더누림 플랫폼 운영 광주', '신청 절차: 광주 청년지...
#
#                                            reference
# 0                                울산광역 동구 일리정책과 일리정책팀
# 1  지역의 산업에 맞는 인력양성과 취업역량 강화 교육, 원활한 구인 구직 매칭을 지원합니다.
# 2                                  만 18세부터 39세까지입니다.
# 3                                             경기도 광주
# 4                                   광주 청년지원센터 홈페이지 접
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_input  300 non-null    object
#  1   qa_context  300 non-null    object
#  2   reference   300 non-null    object
# dtypes: object(3)
# memory usage: 7.2+ KB
# None

# %%
    # Vector Store
    embedding_model = OpenAIEmbeddings(model="text-embedding-ada-002")  # Vector DB와 동일한 1536 차원 모델 사용
    COLLECTION_NAME = "policy"
    PERSIST_DIRECTORY = "data/vector_store/policy"

    # vector store 연결
    vector_store = Chroma(
        embedding_function=embedding_model,
        collection_name=COLLECTION_NAME,
        persist_directory=PERSIST_DIRECTORY
    )

# %%
# 평가하려는 RAG 시스템

from operator import itemgetter

# Retriever 설정 - 검색 설정
retriever = vector_store.as_retriever(
    search_type="mmr",
    search_kwargs={
        "k": 5,
        "fetch_k": 10,
        "lambda_mult": 0.2
    }
)

# LLM 구성
messages = [
            ("ai", """
            당신은 유능한 청년지원정책 추천 전문 AI 챗봇입니다.
            주요 목표는 사용자의 요청에 따라 알맞는 청년지원정책을 추천하는 것입니다.
             
            다음은 답변을 작성하기 위한 지침(guidelines)입니다:
            1. 주어진 context(데이터 및 검색 결과)를 바탕으로만 대답해주세요.
            2. 모든 답변은 학습된 정책 데이터를 바탕으로 반드시 사용자가 물어본 질문에 대한 정확한 정보만 작성하세요.
            3. 예를 들어, 사용자가 "서울시 주거 정책을 알려줘" 라고 질문했다면 "서울 시민"이 지원대상이 되는 답변만을 생성해야하며 "고양시"나 "경남" 지역에서 시행 중인 정책을 답변으로 가져와서는 안됩니다.
            4. 답변에 불필요한 정보는 제공하지 마세요.
            5. 해당 데이터에 없는 내용은 검색해서 대답세요. 다만, 검색 도구(TavilySearch 등)에서도 찾을 수 없는 경우, 답변을 추측하거나 임의로 생성하지 말고 "잘 모르겠습니다."라고 답변하세요.검색으로도 정보를 찾을 수 없을 경우 답변을 추측하거나 임의로 생성하지말고, "잘 모르겠습니다."라고 답변하세요.
            6. 답변은 체계적이고, 비전문가 사용자도 이해하기 쉽게 답변을 작성하세요.
            7. 항상 최신의 정확한 정보를 제공하기 위해 노력하세요.
            8. 질문을 완전히 이해하지 못할 경우, 구체적인 질문을 다시 받을 수 있도록 사용자에게 유도 질문을 하세요.     
            9. 답변 스타일은 간결하고 논리적으로 작성하세요. 필요시, 리스트 형식으로 정리하세요.
            10. 답변이 사용자가 질문한 내용에 부합하는지 다시 한번 확인하세요.
            11. 질문을 만들 때 "제공된 문맥에서", "문서에 설명된 대로", "주어진 문서에 따라" 또는 이와 유사한 말을 하지 마세요.
            
            위 지침을 따라 사용자의 요청에 맞는 적절한 청년지원정책 정보를 제공합니다.

            {context}")"""),
            MessagesPlaceholder("history"), 
            ("human", "{question}")
]

prompt_template = ChatPromptTemplate(messages)
model = ChatOpenAI(model='gpt-4o', temperature=0)

query = "user_input"

# search_policy tool 정의
@tool
def search_policy(query:str) -> list[Document]:
    """
    Vector Store에 저장된 청년 지원 정책과 해당 정책의 정보를 검색한다.
    이 도구는 청년 지원 정책 관련 질문에 대해 실행한다.
    """
    result = retriever.invoke(query) 
    if len(result): 
        return result
    else:
        return [Document(page_content = "검색 결과가 없습니다.")]
    
    # TavilySearch web 검색
tavily_search = TavilySearchResults(max_results=2)

# 최종 응답 생성
def generate_final_input(query, result_from_db, result_from_web):
    combined_context = [
        f"저장된 데이터에서 찾은 정보:\n{result_from_db}\n",
        "실시간 웹 검색에서 확인된 정보:\n"
    ]

    if isinstance(result_from_web, list):
        combined_context.extend(
            [f"[{idx}] {result.get('title', '제목 없음')}: {result.get('content', '내용 없음')}"
             for idx, result in enumerate(result_from_web, start=1)]
        )
    else:
        combined_context.append("웹 검색 결과를 처리할 수 없습니다.")
    
    combined_context = "\n".join(combined_context)
    return f"{combined_context}를 참고해서 {query}에 대한 답변 생성"


# 실행에 필요한 인풋 설정
runnable = {
    'context': RunnableLambda(lambda x: retriever.invoke(x['question'])),
    'question': itemgetter("question"),
    'history': itemgetter('history')
} | prompt_template | model | StrOutputParser()

# chain 설정
chain = RunnableWithMessageHistory(
    runnable=runnable,
    get_session_history=lambda session_id: memory.chat_memory,
    input_messages_key="question",
    history_messages_key="history"
)

# DB 검색
result_from_db = search_policy(query)

# Tavily 검색(web 검색)
try:
    result_from_web = tavily_search.invoke(query)
    if not result_from_web or not isinstance(result_from_web, list):
        raise ValueError("유효하지 않은 Tavily 검색 결과")
except Exception as e:
    result_from_web = [{"title": "오류 발생", "content": str(e)}]

# 최종 응답 생성
final_model = ChatOpenAI(model="gpt-4o-mini")
final_input = generate_final_input(query, result_from_db, result_from_web)
final_response = final_model.invoke(final_input)

# %%
# context들과 모델답변을 응답 받아 eval_dataset(eval_df)에 추가.

context_list = []
response_list = []

for user_input in eval_df['user_input']:
    # 정책 검색
    result_from_db = search_policy.invoke(user_input)
    result_from_web = tavily_search.invoke(user_input)
    
    final_input = generate_final_input(user_input, result_from_db, result_from_web)
    final_response = final_model.invoke(final_input)
    
    context = [f"{result_from_db}, {result_from_web}"]
    context_list.append(context)
    response_list.append(final_response.content)    # content만 response_list에 저장

# %%
# 확인
response_list
# context_list
# Out:
# [AIMessage(content='울산 동구 지역산업맞춤형 청년일자리 사업의 주관 기관은 울산광역시 동구 일자리정책과입니다. 이 사업의 주요 내용은 지역 산업 수요에 맞는 인력 양성과 취업 역량 강화 교육을 통해 지역 고용 문제를 해결하는 것입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 3085, 'total_tokens': 3154, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-078e4b0b-2461-436c-a82e-7062bb65d04d-0', usage_metadata={'input_tokens': 3085, 'output_tokens': 69, 'total_tokens': 3154, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산 동구 지역산업맞춤형 청년일자리 사업의 지원 내용은 다음과 같습니다:\n\n1. **사업 목표**: 양질의 일자리 창출을 통해 지역 경제를 활성화하고, 청년 인구 유입을 통해 도시 경쟁력을 강화하는 것을 목표로 합니다.\n\n2. **교육 및 훈련**: 지역의 산업 수요에 맞는 인력 양성을 위한 교육훈련 프로그램을 실시합니다. 이는 지역 고용 문제 해결을 위한 취업 역량 강화 교육을 포함합니다.\n\n3. **취업 연계**: 지역 산업 수요에 맞춘 원활한 구인 구직 매칭을 지원하는 사업이 운영됩니다.\n\n4. **사업 운영 방법**: 사업기관과 약정 체결을 통해 추진됩니다.\n\n5. **사업 운영 기간**: 약정 체결일로부터 2024년 12월까지 진행됩니다.\n\n6. **사업 신청 기간**: 상시 신청이 가능합니다.\n\n7. **대상 연령**: 만 18세에서 39세까지의 청년이 대상입니다.\n\n8. **거주지 및 소득**: 동구 지역의 미취업 청년을 대상으로 하며, 소득 기준에 대한 구체적인 내용은 명시되어 있지 않습니다.\n\n9. **주관 및 운영 기관**: 울산광역시 동구 일자리정책과 일자리정책팀이 주관하며, 운영 기관은 주관 기관과 동일합니다. 연락처는 052-209-4552입니다.\n\n이 사업은 청년의 취업 역량을 높이고 지역의 고용 문제를 해결하는 데 기여하고자 합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 356, 'prompt_tokens': 3124, 'total_tokens': 3480, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-51ea897b-2403-450f-9002-4eb5e37487ae-0', usage_metadata={'input_tokens': 3124, 'output_tokens': 356, 'total_tokens': 3480, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산 동구 지역산업 청년일자리 사업의 신청 가능한 연령대는 만 18세에서 만 34세까지입니다. 만약 만 35세에서 39세에 해당하는 경우에는 방문신청이 필요하며, 사전 약속이 있어야 합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 2973, 'total_tokens': 3036, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-10d55e31-6100-45e5-ab64-2342112f1221-0', usage_metadata={'input_tokens': 2973, 'output_tokens': 63, 'total_tokens': 3036, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content="광주시 청년지원센터 '더누림 플랫폼' 운영 사업의 주관 기관은 경기도 광주시입니다. 이 사업은 광주시 청년전용공간 운영을 통해 청년들의 역량 강화와 여가 지원을 목표로 하고 있습니다.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 2853, 'total_tokens': 2909, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-2d1249d2-01e2-40e0-93ba-442600316637-0', usage_metadata={'input_tokens': 2853, 'output_tokens': 56, 'total_tokens': 2909, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='다음은 광주광역시에서 청년들을 위한 다양한 지원 사업에 대한 정보입니다.\n\n1. **청년지원센터 더누림 플랫폼 운영**\n   - **지원 내용**: 민간위탁 운영 사업, 청년 전용 공간 운영, 역량강화 및 여가지원 사업.\n   - **운영 기간**: 2024년 1월부터 12월까지.\n   - **신청 기간**: 상시 모집.\n   - **대상**: 만 19세 ~ 39세, 광주시 거주 청년 누구나 신청 가능.\n   - **신청 절차**: 광주시 청년지원센터 홈페이지를 통해 신청 접수.\n   - **주관 및 운영 기관**: 경기도 광주시, 광주시 청년지원센터 더누림 플랫폼.\n\n2. **청년 올라 광주시**\n   - **지원 내용**: 취업 준비 및 청년 역량 강화를 위한 프로그램 운영(어학, 자격증 응시료 지원, 취업 역량 강화 교육 등).\n   - **운영 기간**: 2024년 1월부터 12월까지.\n   - **신청 기간**: 상시 모집.\n   - **대상**: 만 19세 ~ 39세, 광주시 소재 거주, 재학, 활동하는 청년.\n   - **신청 절차**: 광주시 청년지원센터 누리집을 통한 온라인 신청 접수.\n   - **주관 및 운영 기관**: 경기도 광주시, 주관기관과 동일.\n\n3. **광주 광산 청년도전지원사업**\n   - **지원 내용**: 밀착 상담, 사례 관리, 진로 탐색, 취업 역량 강화 등 맞춤형 지원.\n   - **운영 기간**: 2024년 2월 1일부터 대상자 모집 마감 시까지.\n   - **신청 기간**: 상시 모집.\n   - **대상**: 만 18세 ~ 39세, 구직단념 청년 및 생계형 아르바이트 청년 등.\n   - **신청 절차**: 온라인 워크넷 및 오프라인 방문 상담 가능.\n   - **주관 및 운영 기관**: 광산구청년도전지원센터.\n\n4. **청년 마음 건강 지원 사업**\n   - **지원 내용**: 심리지원, 상담, 맞춤형 지원(최대 12개월).\n   - **운영 기간**: 2024년 1월부터 12월까지.\n   - **신청 기간**: 상시 모집.\n   - **대상**: 자립 준비 청년, 보호 연장 아동, 정신 건강 복지센터 연계자 등.\n   - **신청 절차**: 주소지 읍면동에서 신청 접수.\n   - **주관 및 운영 기관**: 경기도 광주시.\n\n5. **서울 청년포털 청년 몽땅 정보통 운영**\n   - **지원 내용**: 중앙정부와 지자체별 청년정책 정보 통합 추진.\n   - **신청 기간**: 상시 모집.\n   - **대상**: 제한 없음.\n   - **주관 및 운영 기관**: 서울시청 미래청년기획단.\n\n각 프로그램은 청년의 다양한 필요를 충족시키기 위해 설계되었으며, 신청 방법과 조건이 다르므로 해당 기관의 웹사이트를 통해 구체적인 정보와 신청 절차를 확인하시기 바랍니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 750, 'prompt_tokens': 3283, 'total_tokens': 4033, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-895928d8-71ff-49d9-a1d9-1bd8b84fd1fa-0', usage_metadata={'input_tokens': 3283, 'output_tokens': 750, 'total_tokens': 4033, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='광주시 청년지원센터 더누림 플랫폼의 지원 대상 연령은 만 19세에서 39세까지입니다. 이 지원은 광주시에 거주하는 청년 누구나 신청할 수 있으며, 사업 신청은 연중 상시로 가능합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 3444, 'total_tokens': 3500, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-77684ad2-fc5c-4db1-b330-253a5b8a5c93-0', usage_metadata={'input_tokens': 3444, 'output_tokens': 56, 'total_tokens': 3500, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='오산시의 "자아회복탄력성 개인심리상담" 정책의 주관 기관은 경기도 오산시입니다. 이 정책은 오산청년일자리지원센터 "이루잡"에서 운영되고 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 2761, 'total_tokens': 2815, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-a5e62b97-6f76-4d5d-b0b6-0a95b25edf62-0', usage_metadata={'input_tokens': 2761, 'output_tokens': 54, 'total_tokens': 2815, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='오산시의 "자아회복탄력성 개인심리상담" 정책의 지원 내용은 다음과 같습니다:\n\n1. **상담 진행**: 최초 신청 후 상담사와 개별 일정을 조율하여 추가 상담 진행이 가능하며, 1회당 50분씩 최대 6회까지 제공됩니다.\n2. **상담 목적**: 자아회복탄력성을 향상시키고, 역경지수 회복 및 대인관계 소통 향상을 도모합니다. 또한 내면아이 치유와 마음챙김, 인지행동과 같은 심리적 접근을 포함합니다.\n3. **사업 기간**: 2024년 3월 26일부터 12월 중까지 운영되며, 매주 화요일 14:00~20:00에 진행됩니다.\n4. **대상**: 만 19세에서 39세의 오산시에 거주하는 청년들입니다.\n5. **주관 및 운영 기관**: 경기도 오산시와 오산청년일자리지원센터(이루잡)가 주관하며, 상담 관련 문의는 전화(031-8036-8046)를 통해 가능합니다.\n\n이 정책은 오산시 청년들의 건강한 심리건강 회복을 목적으로 하고 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 280, 'prompt_tokens': 3781, 'total_tokens': 4061, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-dd739ea8-8dff-4c4e-909a-7f6c30390c3e-0', usage_metadata={'input_tokens': 3781, 'output_tokens': 280, 'total_tokens': 4061, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='오산시의 "자아회복탄력성 개인심리상담" 프로그램의 운영 기관은 **오산청년일자리지원센터 이루잡**입니다. 이 센터는 청년들의 심리 건강 회복을 위한 상담 프로그램을 운영하고 있습니다. 상담은 개인별로 진행되며, 상담사는 신청 후 개별 일정을 조율하여 최대 6회까지 50분씩 상담을 제공합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 2810, 'total_tokens': 2903, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-d449ca57-eaf9-4818-bb93-e36f8854d18d-0', usage_metadata={'input_tokens': 2810, 'output_tokens': 93, 'total_tokens': 2903, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산 희망상가 품은 청년희망주택 건립 정책의 사업 운영 기간은 2019년 8월부터 2024년 1월까지입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 2760, 'total_tokens': 2801, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-249596d3-d524-4c3b-8b8f-685b6b93f9d7-0', usage_metadata={'input_tokens': 2760, 'output_tokens': 41, 'total_tokens': 2801, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산 희망상가 품은 청년희망주택 건립 정책의 지원 대상 연령은 만 18세에서 39세입니다. 이 정책은 청년층의 주거 안정과 창업 기회를 지원하기 위해 마련되었습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 2985, 'total_tokens': 3040, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-70a59497-244c-485c-9ebc-a3a529d7ce55-0', usage_metadata={'input_tokens': 2985, 'output_tokens': 55, 'total_tokens': 3040, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산 희망상가 품은 청년희망주택 건립 정책의 주관 기관은 울산광역시 건축정책과 주거지원팀입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 3049, 'total_tokens': 3088, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-8708f209-b03c-4591-b31b-1106ae22689a-0', usage_metadata={'input_tokens': 3049, 'output_tokens': 39, 'total_tokens': 3088, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='예술인 고용보험 정책의 주관 기관은 **고용노동부**입니다. 이 정책은 예술인과 사업주가 공동으로 마련한 기금으로, 실직 예술인의 생활 안정과 재취업을 지원하는 사회보험제도입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 4945, 'total_tokens': 5005, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-4afb2182-71b7-4fdb-a647-856e82b512b1-0', usage_metadata={'input_tokens': 4945, 'output_tokens': 60, 'total_tokens': 5005, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='예술인 고용보험 정책에 대한 정보는 다음과 같습니다:\n\n### 정책 개요\n예술인 고용보험 정책은 고용보험의 사각지대에 놓여 있던 프리랜서 예술인들을 위한 제도로, 실업급여와 출산전후 급여를 통해 고용안전망을 확충하는 것을 목적으로 합니다.\n\n### 지원 내용\n- **고용보험 적용**: 예술인과 사업주가 각각 소득의 0.8%씩 부담하여 총 1.6%의 보험료를 납부합니다.\n- **실업급여**:\n  - 이직일 이전 24개월 동안 피보험 단위기간이 9개월 이상인 경우 수급 가능.\n  - 구직급여일액은 기초일액의 60%이며, 상한액은 66,000원입니다.\n  - 지급기간은 피보험 기간 및 연령에 따라 120일에서 270일 사이입니다.\n- **출산전후 급여**:\n  - 출산, 유산, 사산 전 피보험 단위기간이 3개월 이상일 것.\n  - 지급수준은 1년간 월평균 보수의 100%로, 상한액은 월 200만원, 하한액은 60만원입니다.\n\n### 신청 요건\n- **대상**: 문화예술용역 계약을 체결하고 다른 사람을 사용하지 않고 직접 노무를 하는 프리랜서 예술인.\n- **거주지 및 소득**: 근로자가 아닌 예술인으로, 문화예술용역계약을 체결한 사람.\n- **신청 절차**: 기본적으로 사업주가 고용보험 가입 신청을 하며, 예술인이 직접 신청할 수도 있습니다.\n\n### 추가 정보\n- **중복수혜 제한**: 월평균소득 50만원 미만인 단기예술인에게는 중복수혜가 불가합니다.\n- **신청 기간**: 상시 운영 중.\n\n### 결론\n예술인은 비자발적으로 실직할 경우 실업급여를 신청할 수 있으며, 이를 통해 생계 안정과 재취업을 지원받을 수 있습니다. 실업급여와 출산전후 급여의 수급 요건을 충족해야 하며, 신청 과정에서 필요한 서류를 준비해야 합니다. \n\n이 정책은 예술인들이 더욱 안정된 환경에서 활동할 수 있도록 돕기 위한 중요한 제도입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 543, 'prompt_tokens': 6971, 'total_tokens': 7514, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-5aa9ad1f-75e4-476e-9ac1-48757b92ced2-0', usage_metadata={'input_tokens': 6971, 'output_tokens': 543, 'total_tokens': 7514, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='예술인 고용보험 정책에 따라 출산전후급여의 지급 수준은 고용보험 가입 여부에 따라 다르게 적용됩니다. 출산일 직전 1년 또는 18개월 동안의 월평균 보수의 100%가 지급되며, 하한액은 60만원, 상한액은 200만원입니다. \n\n따라서, 2024년 예술인 출산전후급여의 상한액은 월 200만원입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 106, 'prompt_tokens': 4528, 'total_tokens': 4634, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-eea699d7-91ee-49bd-a242-0fa62bb85f57-0', usage_metadata={'input_tokens': 4528, 'output_tokens': 106, 'total_tokens': 4634, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산웹툰캠퍼스 운영의 주관 기관은 울산광역시 문화예술과 문화산업팀입니다. 운영 기관은 울산정보산업진흥원 울산웹툰캠퍼스입니다. 이 캠퍼스는 예비 및 현업 웹툰 작가들을 위한 창작 지원 공간으로, 다양한 교육 프로그램과 최신 웹툰 장비를 제공하고 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 2708, 'total_tokens': 2799, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-4d86b311-26dc-4855-8958-6d0f31d8729f-0', usage_metadata={'input_tokens': 2708, 'output_tokens': 91, 'total_tokens': 2799, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산웹툰캠퍼스 운영의 지원대상은 만화 웹툰 작가 및 웹툰 산업 분야에 진로를 희망하는 만 19세에서 39세 사이의 청년들입니다. 이 캠퍼스는 예비 작가들에게 창작 교육시설을 제공하고, 인력 양성 사업을 통해 지역 만화 웹툰 산업을 육성하고 일자리를 창출하는 것을 목표로 하고 있습니다. \n\n구체적으로, 지원 내용에는 작가입주실 공간 운영, 창작 교육시설 운영, 그리고 인력 양성 사업이 포함되어 있습니다. 이 사업은 2024년 1월부터 12월까지 운영되며, 신청은 상시로 가능합니다. \n\n주관 기관은 울산광역시 문화예술과 문화산업팀이며, 운영 기관은 울산정보산업진흥원 울산웹툰캠퍼스입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 199, 'prompt_tokens': 3583, 'total_tokens': 3782, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-1ef08989-d583-4fcc-9e4b-092ca90c97b2-0', usage_metadata={'input_tokens': 3583, 'output_tokens': 199, 'total_tokens': 3782, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산웹툰캠퍼스 운영의 사업 운영 기간은 2024년 1월부터 12월까지입니다. 이 프로그램은 만화 웹툰 산업 육성을 목표로 하며, 만화 웹툰 작가와 웹툰 산업 분야 진로 청년들을 지원합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 2943, 'total_tokens': 3010, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-12366710-bfbc-498a-a5cf-a856ab5b5a0e-0', usage_metadata={'input_tokens': 2943, 'output_tokens': 67, 'total_tokens': 3010, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년 월세 지원 사업은 만 19세에서 34세 사이의 독립 거주 무주택 청년을 대상으로 한시적으로 시행되는 복지 정책입니다. 이 사업에서는 월세를 지원하며, 지원 금액은 매월 최대 20만원까지 가능합니다. 지원 기간은 최대 12개월이며, 임차보증금과 관리비는 제외되고 실제 납부하는 월세에 대해서만 지원됩니다. \n\n신청 후 지원금 지급은 보통 1~2개월 이내에 이루어지며, 지급일은 매달 마지막 주에 진행됩니다. 청년 월세 지원 사업은 경제적 어려움을 겪는 청년층의 주거비 부담을 덜어주기 위한 목적을 가지고 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 4590, 'total_tokens': 4752, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-3c91dc23-b43b-4c84-9096-0e2f81f6e66e-0', usage_metadata={'input_tokens': 4590, 'output_tokens': 162, 'total_tokens': 4752, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년 월세 지원사업의 신청 기간은 2024년 2월 26일부터 2025년 2월 25일까지 1년간 수시로 신청이 가능합니다. 만약 2024년 2월에 신청하면 3월부터 바로 지원받을 수 있으며, 이후 신청한 달을 기준으로 소급 적용되어 지원이 이루어집니다. 지원 내용은 월 최대 20만원의 임차료 지원으로, 실제 납부하는 월세의 최대 20만원까지 지원됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 114, 'prompt_tokens': 4837, 'total_tokens': 4951, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-6eb38bac-80f0-4af5-8f95-c5ac6d209261-0', usage_metadata={'input_tokens': 4837, 'output_tokens': 114, 'total_tokens': 4951, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content="청년 월세 지원사업은 저소득 청년들이 주거비 부담을 덜 수 있도록 다양한 지원을 제공하는 정책입니다. 각 지역에서 운영하는 이 사업의 주요 내용은 다음과 같습니다:\n\n1. **지원 금액 및 기간**:\n   - 대부분의 청년 월세 지원사업은 월 최대 20만 원을 지원하며, 지원 기간은 최대 12개월입니다.\n   - 예를 들어, 청년 월세지원사업에서는 총 지원 금액이 최대 240만 원에 이를 수 있습니다.\n\n2. **대상 및 자격 요건**:\n   - 일반적으로 지원 대상은 만 19세에서 34세 사이의 무주택 저소득 청년입니다.\n   - 부모와 별도로 거주해야 하며, 소득 기준은 기준 중위소득의 60% 이하인 경우가 많습니다.\n   - 특정 지역의 경우 (예: 경남도민) 추가적인 지역 조건이 있을 수 있습니다.\n\n3. **신청 방법**:\n   - 대부분의 경우 온라인 신청이 가능하며, '복지로'와 같은 플랫폼을 통해 신청할 수 있습니다. \n   - 또한, 오프라인으로는 읍면동 행정복지센터에서 신청할 수 있습니다.\n\n4. **중복 지원 여부**:\n   - 청년 월세 지원금을 받고 있는 경우, 다른 주거 지원 프로그램과 중복하여 혜택을 받을 수 있는 경우가 많습니다. 하지만 이미 지원을 받고 있는 경우는 신청할 수 없습니다.\n\n5. **기타 정보**:\n   - 청년 월세 지원금을 받는 경우 연말정산 시 월세 세액공제를 받을 수 있습니다.\n   - 신청 기간은 지역에 따라 상시 또는 특정 기간으로 설정되며, 예산 소진 시까지 신청이 가능할 수 있습니다.\n\n이와 같은 정보는 각 지역의 특성과 정책에 따라 다를 수 있으므로, 해당 지역의 주관 기관에 확인하는 것이 중요합니다.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 419, 'prompt_tokens': 3971, 'total_tokens': 4390, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-20957e59-22b0-4e1e-9d0b-7e26f49af9fc-0', usage_metadata={'input_tokens': 3971, 'output_tokens': 419, 'total_tokens': 4390, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년일자리창출사업의 운영 기간은 2024년 1월 1일부터 2024년 12월 31일까지입니다. 이 사업은 서울특별시에서 진행되며, 만 19세에서 39세의 미취업 청년을 대상으로 합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 2525, 'total_tokens': 2589, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-1c2edb17-8095-4241-831d-44950c0ae88d-0', usage_metadata={'input_tokens': 2525, 'output_tokens': 64, 'total_tokens': 2589, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년 관련 정책 및 지원 사업에 대한 정보는 다음과 같습니다:\n\n1. **청년 신규창업자 발굴 육성사업 (충청남도)**\n   - **지원 내용**: 지역 창업 아이템 아이디어를 활용한 창업자 발굴\n   - **신청 기간**: 미정\n   - **지원 규모**: 3팀\n   - **연령**: 만 19세 ~ 45세\n   - **거주지 및 소득**: 공주시 주소의 청년 예비 창업자, 3년 이내 창업자, 미취업자\n   - **신청 절차**: 기관에 신청\n   - **제출 서류**: 참가신청서, 사업계획서, 주민등록본, 초본, 사업자등록사실증명원, 개인정보 수집 동의서\n   - **주관 기관**: 공주시\n\n2. **2024년 전통시장 청년상인 지원사업 (전라북도)**\n   - **지원 내용**: 창업지원, 성장지원, 판로지원\n   - **신청 기간**: 상시\n   - **연령**: 만 18세 ~ 39세\n   - **거주지 및 소득**: 전통시장 상점가에서 영업하는 만 39세 이하 청년상인\n   - **신청 절차 및 제출 서류**: 지원별 다름 (첨부 파일 참고)\n   - **주관 기관**: 재 청년상인육성재단\n\n3. **청년 면접준비비 지원사업 (경상북도)**\n   - **지원 내용**: 면접비 지원\n   - **신청 기간**: 2024년 07월 01일 ~ 2024년 12월 31일\n   - **연령**: 만 19세 ~ 39세\n   - **주관 기관**: 경주시\n\n4. **청년 생활클리닉 (서울특별시)**\n   - **지원 내용**: 진로설계 도움, 재무관리 교육\n   - **신청 기간**: 미정\n   - **연령**: 만 19세 ~ 39세\n   - **신청 절차**: 구글폼 신청\n   - **주관 기관**: 종로구청 일자리경제과\n\n5. **2024년 청년도전 지원사업 (경상북도)**\n   - **지원 내용**: 구직단념청년 발굴 및 밀착 상담, 진로탐색, 취업역량 강화\n   - **사업 운영 기간**: 2024년 03월 01일 ~ 2024년 12월 31일\n   - **사업 신청 기간**: 2024년 03월 01일 ~ 2024년 12월 31일\n   - **연령**: 만 19세 ~ 39세\n   - **주관 기관**: 경상북도\n\n이 외에도 정부의 청년 일자리 창출을 위한 다양한 세제지원 혜택이 나이 상한선을 34세로 확대하는 등의 정책이 추진되고 있습니다. 각 정책에 대한 자세한 사항은 관련 기관에 문의하시기 바랍니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 714, 'prompt_tokens': 2474, 'total_tokens': 3188, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-570ba05e-25c9-426d-99e1-0d4aefe1f1e1-0', usage_metadata={'input_tokens': 2474, 'output_tokens': 714, 'total_tokens': 3188, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년일자리창출사업의 주관 기관은 은평구청 사회적경제과 청년지원팀입니다. 이 사업은 서울특별시에서 진행되며, 지원 내용은 일 경험 및 취업역량 강화 사업입니다. 운영 기간은 2024년 1월 1일부터 2024년 12월 31일까지이며, 참여 대상은 만 19세에서 39세 사이의 미취업자입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 3126, 'total_tokens': 3223, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-b1c91715-668e-4b1f-83bc-a35e5591f8dd-0', usage_metadata={'input_tokens': 3126, 'output_tokens': 97, 'total_tokens': 3223, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년안심주택 공급 매입 정책을 주관하는 기관은 **전략주택공급과**입니다. 이 기관은 청년층의 주거 안정을 도모하고 지역 경제 활성화를 위해 민간 소유 토지를 체계적으로 개발하고, 공공 지원을 통해 저렴하고 쾌적한 주택을 공급하는 역할을 하고 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 3354, 'total_tokens': 3436, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-44b3d419-9abc-46fb-b597-5925c2f4d6b9-0', usage_metadata={'input_tokens': 3354, 'output_tokens': 82, 'total_tokens': 3436, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년안심주택 공급 매입 정책의 지원 연령대는 만 19세에서 39세입니다. 이 정책은 역세권 간선도로변의 민간소유 토지를 체계적으로 개발하여 청년층에게 쾌적하고 저렴한 주택을 공급하고자 하는 목적을 가지고 있습니다. 청년층의 주거안정과 지역경제 활성화를 도모하기 위한 정책입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 2948, 'total_tokens': 3041, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-fa1c9372-a879-43a2-9b01-a7f3e2109735-0', usage_metadata={'input_tokens': 2948, 'output_tokens': 93, 'total_tokens': 3041, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년안심주택 공급 매입 정책에 대한 공공임대 문의 전화번호는 **1600-3456**입니다. 이는 서울주택도시공사의 콜센터 번호로, 청년안심주택 관련 문의를 할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 3068, 'total_tokens': 3124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-b26fe024-d75a-4f02-9cf5-feef670c11af-0', usage_metadata={'input_tokens': 3068, 'output_tokens': 56, 'total_tokens': 3124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='청년정책에 관한 여러 지원 제도와 프로그램이 있습니다. 다음은 해당 정책들에 대한 요약입니다:\n\n1. **청년이어드림지원금 (제주특별자치도)**:\n   - **지원 내용**: 미취업 청년에게 10~60만원, 취업 청년에게 5~25만원 지급.\n   - **대상**: 도내 청년 1,500명 (5개년 계획).\n   - **사업 기간**: 2024년 1월 1일 ~ 2024년 12월 31일.\n   - **신청 방법**: 지역화폐 탐나는전으로 지급되며, 단계별 상담 및 피드백을 통해 지원금 지급.\n\n2. **남동구 청년단 운영 (인천광역시)**:\n   - **지원 내용**: 활동 지원, 회의 수당, 정책 워크숍, 토크콘서트.\n   - **대상**: 만 19세 ~ 39세 청년 30명.\n   - **사업 운영 기간**: 2024년 1월 ~ 12월.\n   - **신청 절차**: 구 홈페이지에서 신청서 및 증빙서류 제출.\n\n3. **찾아가는 청년정책 소통학교 (전라북도)**:\n   - **지원 내용**: 청년 정책 이해도 함양 및 네트워킹 장 마련.\n   - **대상**: 도내 청년 정책에 관심 있는 만 19세 ~ 34세 청년.\n   - **사업 운영 날짜**: 2024년 4월 25일.\n   - **신청 방법**: 전북청년허브센터 홈페이지를 통한 온라인 신청.\n\n4. **군복무 청년 상해보험 지원 (충청남도)**:\n   - **지원 내용**: 군복무 중 상해보험 자동 가입, 11개 항목 보장.\n   - **대상**: 공주시에 주소를 둔 현역 군복무 청년 (약 614명).\n   - **사업 운영 기간**: 2024년 3월 ~ 2025년 2월.\n   - **신청 방법**: 보험사에 전화 신청.\n\n5. **청년정책위원회 운영 (부산광역시)**:\n   - **지원 내용**: 청년 정책 추진 계획 수립, 평가 및 심의 의결.\n   - **대상**: 만 18세 ~ 39세 청년.\n   - **신청 방법**: 위촉직 위원으로 참여, 공고 확인 후 신청.\n\n이 외에도 각각의 지역 및 기관에서 청년들을 위한 다양한 지원 정책이 시행되고 있으며, 청년들이 자립할 수 있도록 여러 방면에서 도움을 주고 있습니다. 각 정책의 세부사항과 신청 방법은 해당 기관의 공식 홈페이지나 공고를 통해 확인하는 것이 좋습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 630, 'prompt_tokens': 4272, 'total_tokens': 4902, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-f57efa05-2f54-4cae-bca7-4e2fd2bfd922-0', usage_metadata={'input_tokens': 4272, 'output_tokens': 630, 'total_tokens': 4902, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='동차부품구 청년일자리 지원 정책의 사업 운영 기간은 2023년 1월 1일부터 2024년 12월 31일까지입니다. 이 정책은 광주광역시에서 시행되며, 지원 내용으로는 신규 채용 청년 근로자 인건비, 집체 교육, 네트워킹 지원 등이 포함됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 3662, 'total_tokens': 3743, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-10d5cf7f-89d4-4c71-a899-79c1d1d78bef-0', usage_metadata={'input_tokens': 3662, 'output_tokens': 81, 'total_tokens': 3743, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='지능형자동차부품진흥원(KIAPI)이 청년고용창출지원사업의 주관 기관입니다. 이 사업을 통해 94개 기업에 300명의 신규 청년 일자리 창출을 지원하고 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 3861, 'total_tokens': 3914, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-ab61a398-f26c-430b-825c-b126cb4f8b3f-0', usage_metadata={'input_tokens': 3861, 'output_tokens': 53, 'total_tokens': 3914, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content="울산광역시에서는 청년들의 면접 준비를 지원하기 위해 여러 가지 면접 정장 무료 대여 프로그램을 운영하고 있습니다. 다음은 주요 프로그램에 대한 정보입니다:\n\n1. **울산 중구 청년 면접정장 무료대여 '디딤돌 옷드림'**\n   - **지원 내용**: 면접 정장 대여 (남자: 재킷, 바지, 셔츠, 넥타이 / 여자: 재킷, 바지, 치마, 블라우스)\n   - **대여 기간**: 3박 4일, 연 4회 대여 가능\n   - **신청 대상**: 만 19세 ~ 39세의 중구 거주 청년\n   - **신청 방법**: 누리집 본인 인증 후 신청, 현장 방문 대여 가능\n   - **제출 서류**: 신분증, 주민등록초본, 면접 응시 증빙자료\n   - **문의**: 울산광역시 중구청 정책사업단 (052-290-8323)\n\n2. **울산 남구 청년 면접정장 대여사업 '행복드림수트'**\n   - **지원 내용**: 면접 정장 및 구두 대여\n   - **대여 기간**: 1회 3박 4일, 1인 연 3회 대여 가능\n   - **운영 기간**: 2024. 1. 1. ~ 12. 31. (예산 소진 시 마감)\n   - **신청 대상**: 만 19세 ~ 39세의 남구 거주 청년\n   - **신청 방법**: 남구 청년일자리카페 방문 및 신청서 작성\n   - **제출 서류**: 신분증, 주민등록초본, 면접 증빙서류\n   - **문의**: 남구 청년일자리카페 (052-260-2700)\n\n3. **군포시 청년날개 면접정장 무료대여**\n   - **지원 내용**: 면접 정장 무료 대여 (남자: 자켓, 바지, 셔츠 등 / 여자: 자켓, 스커트, 블라우스 등)\n   - **대여 기간**: 1회 3박 4일, 연 5회 대여 가능\n   - **신청 대상**: 만 18세 ~ 39세의 군포시 거주 청년\n   - **신청 방법**: 잡아바 어플라이 온라인 신청\n   - **문의**: 군포시 지역경제과 (031-390-0614)\n\n4. **익산시 청년 면접 정장 대여사업**\n   - **지원 내용**: 미취업 구직 청년에게 면접 정장 무료 대여\n   - **대여 기간**: 3박 4일, 연 3회 대여 가능\n   - **신청 대상**: 만 18세 ~ 39세의 익산시 거주 미취업 청년\n   - **신청 방법**: 온라인 신청 (youthforest.iksan.go.kr)\n   - **문의**: 익산시청 기업일자리과 (063-859-7358)\n\n5. **부산 드림옷장 운영**\n   - **지원 내용**: 면접 정장 무료 대여\n   - **대여 기간**: 3박 4일, 연 5회 대여 가능\n   - **신청 대상**: 만 15세 ~ 34세의 부산 거주 청년\n   - **신청 방법**: 온라인 예약 후 현장 방문\n   - **문의**: 부산경제진흥원\n\n각 프로그램은 신청 방법과 대상, 대여 내용이 다르므로, 필요한 정보를 확인하고 지원하시면 좋습니다.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 844, 'prompt_tokens': 4714, 'total_tokens': 5558, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-e4c9e1bc-d9b8-415b-8d59-cb331bdd2071-0', usage_metadata={'input_tokens': 4714, 'output_tokens': 844, 'total_tokens': 5558, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='여기 울산광역시 중구에서 제공하는 청년 면접정장 무료 대여 프로그램인 "디딤돌 옷드림"에 대한 정보입니다:\n\n### 프로그램 개요\n- **프로그램 이름**: 디딤돌 옷드림\n- **목적**: 청년 실업률 증가와 장기간 취업 준비로 인한 경제적 부담을 경감하여 성공적인 취업 지원.\n  \n### 지원 내용\n- **대여 기간**: 3박 4일, 연 4회 대여 가능.\n- **대여 품목**:\n  - **남성**: 재킷, 바지, 셔츠, 넥타이\n  - **여성**: 재킷, 바지, 치마, 블라우스\n\n### 신청 조건\n- **신청 연령**: 만 19세 ~ 39세\n- **거주지**: 신청일 현재 울산 중구에 거주하는 청년\n- **신청 절차**:\n  - 온라인 신청 후 본인 인증 필요\n  - 현장 방문을 통해 대여 및 반납\n\n### 제출 서류\n- 신분증\n- 주민등록초본\n- 면접 응시 증빙 자료\n\n### 주관 및 운영 기관\n- **주관 기관**: 울산광역시 중구청 정책사업단\n- **연락처**: 052-290-8323\n\n### 추가 정보\n- 지원 연령은 만 19세 이상 ~ 39세 이하입니다. 프로그램은 상시 운영되며, 필요할 경우 대여 기간 연장이 가능합니다. 대여 시 필요한 서류 및 절차에 대한 정보는 공식 웹사이트를 통해 확인할 수 있습니다.\n\n이 프로그램은 청년들에게 면접에 필요한 정장을 무료로 제공하여 취업 비용 부담을 덜어주기 위한 노력의 일환입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 407, 'prompt_tokens': 4181, 'total_tokens': 4588, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-c67eabf4-459f-4b15-95b2-a8acf5eba5c2-0', usage_metadata={'input_tokens': 4181, 'output_tokens': 407, 'total_tokens': 4588, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='다음은 청년 구직자들을 위한 면접 정장 무료 대여 프로그램에 대한 정보입니다:\n\n### 1. 울산 중구 청년 면접정장 무료대여 (디딤돌 옷드림)\n- **정책 이름**: 디딤돌 옷드림\n- **정책 분야**: 일자리 분야\n- **지원 내용**:\n  - 대여 기간: 3박 4일 (연 4회 대여 가능)\n  - 대여 품목: 남성 - 재킷, 바지, 셔츠, 넥타이 / 여성 - 재킷, 바지, 치마, 블라우스\n- **신청 기간**: 상시\n- **신청 자격**: 만 19세 ~ 39세의 중구 거주 청년\n- **신청 절차**: 누리집 본인 인증 후 신청, 현장 방문 대여 및 반납\n- **제출 서류**: 신분증, 주민등록초본, 면접응시 증빙자료\n- **주관 기관**: 울산광역시 중구청 정책사업단 (전화: 052-290-8323)\n\n### 2. 청년드림옷장 면접정장 무료대여 (파주시)\n- **정책 이름**: 청년드림옷장\n- **정책 분야**: 복지·문화 분야\n- **지원 내용**:\n  - 대여 품목: 남성 - 자켓, 바지, 셔츠, 구두, 넥타이, 벨트 / 여성 - 자켓, 스커트, 바지, 블라우스, 구두\n  - 대여 기간: 4박 5일 (연 4회 대여 가능)\n- **신청 기간**: 상시 (2024년 1월~12월 예산 소진시까지)\n- **신청 자격**: 만 18세 ~ 34세의 파주시 거주 청년 구직자\n- **제출 서류**: 신청서, 개인정보 동의서, 주민등록초본, 면접 증빙서류\n- **주관 기관**: 경기도 파주시 청년청소년과 청년지원팀 (전화: 031-940-8664)\n\n### 3. 드림옷장 운영 (부산광역시)\n- **정책 이름**: 드림옷장 운영\n- **정책 분야**: 복지·문화 분야\n- **지원 내용**:\n  - 대여 품목: 남성 - 자켓, 셔츠, 팬츠, 구두, 넥타이, 벨트 / 여성 - 자켓, 셔츠, 치마, 구두\n  - 대여 기간: 연 5회 대여 가능\n- **신청 기간**: 상시\n- **신청 자격**: 만 15세 ~ 34세의 부산 거주 청년\n- **제출 서류**: 주민등록본, 면접 증빙서류 등\n- **주관 기관**: 부산시청 (전화: 해당 기관에 문의)\n\n### 4. 익산시 청년 면접 정장 대여사업\n- **정책 이름**: 2024년 익산시 청년 면접 정장 대여사업\n- **정책 분야**: 일자리 분야\n- **지원 내용**:\n  - 대여 품목: 정장 상하의, 셔츠, 블라우스, 넥타이, 구두\n  - 대여 기간: 3박 4일 (연 3회 대여 가능)\n- **신청 기간**: 상시 (예산 소진시까지)\n- **신청 자격**: 만 18세 ~ 39세의 익산시 거주 미취업 구직 청년\n- **신청 절차**: 온라인 신청\n- **주관 기관**: 익산시 (전화: 063-859-7358)\n\n### 5. 군포청년 면접정장 무료대여\n- **정책 이름**: 청년날개 면접정장 무료대여\n- **정책 분야**: 일자리 분야\n- **지원 내용**:\n  - 대여 품목: 남성 - 자켓, 바지, 셔츠, 구두 / 여성 - 자켓, 스커트, 바지, 블라우스\n  - 대여 기간: 3박 4일 (연 5회 대여 가능)\n- **신청 기간**: 2024년 01월 22일 ~ 2024년 12월 27일 (예산 소진시 종료)\n- **신청 자격**: 만 18세 ~ 39세의 군포시 거주 구직 청년\n- **신청 절차**: 잡아바 어플라이 온라인 신청\n- **주관 기관**: 경기도 군포시 (전화: 031-390-0614)\n\n각 프로그램의 자세한 내용과 신청 방법은 해당 기관의 공식 웹사이트에서 확인할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1107, 'prompt_tokens': 5326, 'total_tokens': 6433, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-dca0145e-4c9e-43db-9028-db90f65b6d4e-0', usage_metadata={'input_tokens': 5326, 'output_tokens': 1107, 'total_tokens': 6433, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='논산시 청년결혼축하금 지원사업의 지원 금액은 부부당 총 700만원입니다. 이 금액은 3차에 걸쳐 분할 지급됩니다: 첫 번째 지급은 300만원, 두 번째와 세 번째 지급은 각각 200만원입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 3464, 'total_tokens': 3527, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-6c07d1a9-3a36-4119-8405-72b664e2adf5-0', usage_metadata={'input_tokens': 3464, 'output_tokens': 63, 'total_tokens': 3527, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='논산시 청년결혼축하금 지원사업의 신청 기간은 2024년 1월 1일부터 2024년 12월 31일까지입니다. 지원금액은 1부부당 700만원으로, 3차에 걸쳐 분할 지급됩니다. (1차 300만원, 2차 200만원, 3차 200만원) 주의할 점은 지원 대상은 2023년 1월 1일 이후 혼인신고를 한 부부이며, 부부 모두 18세 이상 45세 이하이어야 합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 129, 'prompt_tokens': 5624, 'total_tokens': 5753, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-c72cfb2d-259b-4306-b00b-e6ab889b5439-0', usage_metadata={'input_tokens': 5624, 'output_tokens': 129, 'total_tokens': 5753, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='논산시 청년결혼축하금 지원사업의 신청 절차는 다음과 같습니다:\n\n1. **신청 자격 확인**:\n   - 부부 모두 혼인신고일 기준으로 18세 이상 45세 이하여야 합니다.\n   - 혼인신고일 기준으로 부부 중 1명 이상이 논산시에서 6개월 이상 거주해야 합니다.\n\n2. **신청서 작성**:\n   - 지원신청서 및 개인정보 수집, 제공, 이용 동의서 작성이 필요합니다.\n\n3. **신청 방법**:\n   - 논산시 읍·면·동 복지센터를 방문하여 신청할 수 있습니다.\n\n4. **지원금 지급**:\n   - 총 700만원이 3회에 걸쳐 분할 지급됩니다.\n     - 1차 지급: 300만원 (혼인 신고 6개월 경과 후 신청)\n     - 2차 지급: 200만원 (결혼축하금 최초 신청일로부터 2년 후)\n     - 3차 지급: 200만원 (결혼축하금 최초 신청일로부터 3년 후)\n\n신청은 연중 가능하며, 필요한 서류를 준비하여 해당 기관에 방문해 접수하면 됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 271, 'prompt_tokens': 3467, 'total_tokens': 3738, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-6f04d458-f1d5-4353-be9e-80e686647696-0', usage_metadata={'input_tokens': 3467, 'output_tokens': 271, 'total_tokens': 3738, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='유스타트 주택청약 종합저축 지원사업의 주관 기관은 대한적십자사입니다. 이 사업은 자립준비청년의 주거 복지를 위한 주택청약종합저축 납입지원금을 지원하는 프로그램으로, 우리은행과 한국토지주택공사(LH)와 협력하여 진행됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 79, 'prompt_tokens': 3282, 'total_tokens': 3361, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-9c5da172-8e2c-4198-924e-5f35f7f8b7c5-0', usage_metadata={'input_tokens': 3282, 'output_tokens': 79, 'total_tokens': 3361, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='유스타트 주택청약종합저축 지원사업은 만 18세에서 34세 사이의 자립준비청년을 대상으로 합니다. 이 사업은 퇴소 예정이거나 보호가 종료된 아동을 위한 주거 복지를 지원하는 프로그램으로, 총 1,000명을 모집할 예정입니다. 지원 내용으로는 주택청약종합저축 납입 지원금이 포함되어 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 3139, 'total_tokens': 3232, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2944}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-5689fc91-2593-46f6-9728-5c15a105389f-0', usage_metadata={'input_tokens': 3139, 'output_tokens': 93, 'total_tokens': 3232, 'input_token_details': {'audio': 0, 'cache_read': 2944}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='유스타트 주택청약 종합저축 지원사업의 지원 금액은 1인당 월 2만 원씩 24개월 동안 지원됩니다. 즉, 총 지원 금액은 48만 원입니다. 이 프로그램은 자립준비청년의 주거 복지를 위해 주택청약종합저축 납입을 지원하는 사업입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 4560, 'total_tokens': 4641, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-921edd91-dae9-40f8-9f5c-8717fd28c7be-0', usage_metadata={'input_tokens': 4560, 'output_tokens': 81, 'total_tokens': 4641, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='해외취업아카데미 정책을 주관하는 기관은 **고용노동부**입니다. 운영 기관은 **한국산업인력공단**입니다. 이 프로그램은 해외취업을 희망하는 청년들을 대상으로 다양한 교육과 지원을 제공하는 것을 목표로 하고 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 3754, 'total_tokens': 3820, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-4a9933cb-19fe-4434-93bc-78ca3abb5773-0', usage_metadata={'input_tokens': 3754, 'output_tokens': 66, 'total_tokens': 3820, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='해외취업아카데미는 해외취업을 준비하는 청년들을 위한 프로그램으로, 다음과 같은 지원 내용을 제공합니다:\n\n1. **역량 교육**: 해외 취업에 필요한 다양한 역량을 무료로 교육받을 수 있습니다.\n2. **진로 계획 수립**: 진로 계획을 수립하는 데 도움을 줍니다.\n3. **이력서 작성법**: 이력서를 작성하는 방법에 대한 교육이 제공됩니다.\n4. **영문 인터뷰 및 모의면접**: 영어로 진행되는 인터뷰에 대한 준비와 모의면접 기회를 제공합니다.\n5. **어학 교육**: 비즈니스 영어, 독일어, 일본어 등의 언어 교육을 지원합니다.\n\n이 프로그램은 2024년 1월 1일부터 12월 31일까지 운영되며, 사업 신청은 상시 가능하고, 거주지 및 소득에 상관없이 희망하는 구직자는 누구나 신청할 수 있습니다. 주관 기관은 고용노동부이며, 운영 기관은 한국산업인력공단입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 238, 'prompt_tokens': 4350, 'total_tokens': 4588, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-13b9cc5b-a643-4428-9551-72d290b1993b-0', usage_metadata={'input_tokens': 4350, 'output_tokens': 238, 'total_tokens': 4588, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='해외취업아카데미의 사업 운영 기간은 2024년 1월 1일부터 12월 31일까지입니다. 이 프로그램은 해외 취업을 준비하는 청년들에게 필요한 역량 교육을 무료로 지원하며, 상시 신청이 가능합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 3654, 'total_tokens': 3714, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-e4ac9617-37e3-4efd-b22a-d6910890cfc4-0', usage_metadata={'input_tokens': 3654, 'output_tokens': 60, 'total_tokens': 3714, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='안양시에서 운영하는 청년 커리어 고민 솔루션 「ALL Question」에 대한 정보는 다음과 같습니다:\n\n- **이용대상**: 16세 ~ 39세의 안양시 거주 또는 활동 중인 청소년 및 청년\n- **운영시기**: 2024년 3월 4일부터 계속\n- **사업내용**: 청년의 고민을 현직자가 답해주는 온라인 멘토링 서비스로, 진로, 대학, 취업, 이직 등의 분야에 대한 상담 제공\n\n이 프로그램은 청년들이 가지고 있는 다양한 커리어 관련 고민을 해소하기 위해 마련된 온라인 상담 서비스입니다. 청년들이 진로 선택이나 취업, 이직과 같은 문제에 대해 현직자와 직접 상담할 수 있는 기회를 제공합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 177, 'prompt_tokens': 3730, 'total_tokens': 3907, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-603bdd41-102e-4a9e-b8d2-792bbd8248a1-0', usage_metadata={'input_tokens': 3730, 'output_tokens': 177, 'total_tokens': 3907, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
# ...
#  AIMessage(content='청년성장프로젝트 예천군에서 지원하는 교육 분야는 "직장적응 지원"입니다. 이 프로그램은 미취업 청년의 구직 의욕을 고취하고 입직 초기 청년들의 직장 적응을 돕기 위한 맞춤형 심리 상담과 교육을 포함하고 있습니다. 또한, CEO 및 중간관리자를 대상으로 청년 친화 조직문화 교육 사업도 운영될 예정입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 2565, 'total_tokens': 2658, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-d4acd4c1-b8bf-4c90-bd40-83e875d816f6-0', usage_metadata={'input_tokens': 2565, 'output_tokens': 93, 'total_tokens': 2658, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='죄송하지만, "난임부부 원외처방 약제비 지원 영통구" 사업에 대한 구체적인 정보는 제공된 데이터에 포함되어 있지 않습니다. 해당 사업의 주관 기관에 대한 정보는 영통구청 또는 관련 보건소의 공식 웹사이트를 통해 확인하실 수 있습니다. 추가적인 자료가 필요하시다면, 해당 기관에 직접 문의하시기 바랍니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 5109, 'total_tokens': 5197, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-ae211092-da07-4cd1-a9af-e2ee9e092e11-0', usage_metadata={'input_tokens': 5109, 'output_tokens': 88, 'total_tokens': 5197, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='수원시 난임부부 원외처방 약제비 지원 영통구 사업의 신청 절차는 다음과 같습니다:\n\n1. **신청 자격 확인**: 난임부부 시술비 지원사업 대상자 중 지원 회차의 정부 지원금 잔액이 남아 있는 자여야 합니다.\n\n2. **서류 준비**: 다음의 서류를 준비해야 합니다:\n   - 체외 인공 시술 확인서 (병원에서 발급)\n   - 처방전\n   - 약제비 상세내역서 및 약국 영수증 (2개 이상 약 처방 시 필수)\n   - 여성 본인 명의의 통장 사본\n\n3. **신청 방법**:\n   - **관할 보건소 방문**: 회차 시술 완료 후 서류를 첨부하여 1개월 이내에 관할 보건소로 청구합니다.\n   - **온라인 신청**: 정부24를 통해 온라인 신청 가능합니다.\n   - **방문 신청**: 지원 결정 통지서를 발급받았던 관할 보건소를 방문하여 신청할 수 있습니다.\n\n4. **지급 절차**: 여성 주소지 기준으로 의료기관의 시술비 청구금액 확인 후 지급이 이루어지며, 개인 지급에는 시간이 소요될 수 있습니다.\n\n이 절차를 통해 지원을 신청할 수 있습니다. 추가적인 문의가 필요하면 관할 보건소에 직접 문의하는 것이 좋습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 317, 'prompt_tokens': 3635, 'total_tokens': 3952, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-0a1cbb77-0fb3-487c-b0ee-2fb8d4d3a880-0', usage_metadata={'input_tokens': 3635, 'output_tokens': 317, 'total_tokens': 3952, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='수원시 난임부부 원외처방 약제비 지원 영통구 사업에서 제출해야 하는 서류는 다음과 같습니다:\n\n1. 체외 인공 시술확인서 (병원에서 발급)\n2. 처방전\n3. 약제비 상세내역서 (약국영수증 2개 이상, 약 처방 시 약제비 상세 내역서 필수)\n4. 여성 본인명의 통장사본\n\n이러한 서류들을 준비하여 관할 보건소에 청구하면 됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 118, 'prompt_tokens': 5371, 'total_tokens': 5489, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1408}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-e603b7df-fa6f-469b-8a11-5713c2376bd0-0', usage_metadata={'input_tokens': 5371, 'output_tokens': 118, 'total_tokens': 5489, 'input_token_details': {'audio': 0, 'cache_read': 1408}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='2024년 아산시 취업 자격증 응시료 지원 사업의 신청 절차는 다음과 같습니다:\n\n1. **방문 신청**: 아산시청 별관 3층 소회의실에서 직접 방문하여 신청해야 합니다.\n   \n2. **제출 서류**:\n   - 지원 신청서 1부\n   - 응시사실 증명서류 (응시사실 확인서, 성적표, 합격증 등)\n   - 응시료 결제 영수증 (신청인이 실제 부담한 비용이 표기되어 있어야 함)\n   - 주민록초본 (방문접수 시 필요)\n   - 건강보험 자격득실 확인서\n   - 미취업 증빙 자료\n\n신청자는 만 19세에서 64세 사이의 미취업자로, 아산시에 주민등록이 되어 있어야 하며, 2024년 1월 1일 이후 실시된 어학 자격증 시험에 응시한 경우에 해당됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 218, 'prompt_tokens': 4546, 'total_tokens': 4764, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-5da5de6f-d37a-42e0-b09e-0c29de1353e9-0', usage_metadata={'input_tokens': 4546, 'output_tokens': 218, 'total_tokens': 4764, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='2024년 아산 취업 격증 응료 지원 사업의 지원금액은 월 최대 20만원의 임차료를 지원하며, 지원 기간은 최대 12개월입니다. 이를 통해 저소득 청년들이 경제적 부담을 덜 수 있도록 돕는 것이 목적입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 5137, 'total_tokens': 5202, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-7bec9abb-2e1e-4698-a396-f905ae3b6884-0', usage_metadata={'input_tokens': 5137, 'output_tokens': 65, 'total_tokens': 5202, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='2024년 아산시 취업 자격증 응시료 지원 사업의 지원 자격은 다음과 같습니다:\n\n1. **연령**: 신청일 기준 만 19세에서 64세 사이의 미취업자여야 합니다.\n2. **거주 요건**: 시험 응시일부터 계속해서 아산시에 주민등록이 되어 있어야 합니다.\n3. **취업 상태**: 미취업자이어야 하며, 2024년 1월 1일 이후 실시된 어학 자격증 시험에 응시해야 합니다.\n\n이 외에도 지원을 받기 위해서는 신청 절차에 따라 필요한 서류를 제출해야 하며, 자세한 내용은 아산시청 일자리경제과를 통해 확인할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 164, 'prompt_tokens': 4738, 'total_tokens': 4902, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-c3d444cb-d864-43ab-8188-7750cc46380f-0', usage_metadata={'input_tokens': 4738, 'output_tokens': 164, 'total_tokens': 4902, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산 남구 취업역량강화 운영의 주관 기관은 울산광역시 남구 일자리정책과 청년정책팀입니다. 연락처는 052-260-2701입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 2637, 'total_tokens': 2685, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-0f60aaa2-d99f-4d88-95e1-2ab845ed43a9-0', usage_metadata={'input_tokens': 2637, 'output_tokens': 48, 'total_tokens': 2685, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산 남구 취업역량강화 운영의 사업 운영 기간은 2024년 1월부터 12월까지입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 2916, 'total_tokens': 2947, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-63e6b064-4842-40d9-ad42-6f8c9b465883-0', usage_metadata={'input_tokens': 2916, 'output_tokens': 31, 'total_tokens': 2947, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='울산 남구 취업역량강화 운영의 지원 내용은 다음과 같습니다:\n\n- **운영시간**: 월 ~ 금 10:00 ~ 20:00, 토 10:00 ~ 18:00 (3월 ~ 10월)\n- **장소**: 남구 대학로 130, 2층 무거동\n- **운영내용**:\n  - 1:1 취업맞춤 컨설팅 (자기소개서, 진로취업, 면접 컨설팅)\n  - 기업 직무 분석, 위포트 취업 핵심 분석\n  - 화상 면접 공간 및 장비 지원\n  - 오픈 컨설팅\n  - 취업 스터디 및 단기 특강\n  - 공채 시즌 특강\n  - 직무 탐색 및 실전 면접\n  - 1일 면접 완성 프로그램\n  - 청년 정책 특강\n  - 취미 및 선배 멘토링\n  - 취업 토크 콘서트\n\n- **사업 운영 기간**: 2024년 1월 ~ 12월\n- **사업 신청 기간**: 상시\n- **대상 연령**: 만 19세 ~ 39세\n- **거주지 및 소득 요건**: 울산 남구에 거주하는 청년\n- **주관 기관**: 울산광역시 남구 일자리정책과 청년정책팀 (전화: 052-260-2701)\n- **운영 기관**: 울산광역시 남구 청년일자리카페 (전화: 052-226-3190)\n\n이 프로그램은 청년들의 취업 역량을 강화하고, 개인 맞춤형 취업 상담을 제공하는 데 중점을 두고 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 391, 'prompt_tokens': 3032, 'total_tokens': 3423, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-6822052e-2601-4279-bb96-291a9590cfd2-0', usage_metadata={'input_tokens': 3032, 'output_tokens': 391, 'total_tokens': 3423, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='엔젤공방거리 조성 사업에서 지원되는 임차료 비율은 입점 첫해에 한해 50%입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 6044, 'total_tokens': 6075, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-4f7de264-78b6-4df0-a054-57e1a8edb7d3-0', usage_metadata={'input_tokens': 6044, 'output_tokens': 31, 'total_tokens': 6075, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='엔젤공방거리 조성 사업의 주관 기관은 강동구청 기획경제국 일자리정책과입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 2922, 'total_tokens': 2952, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-43e420d9-dedf-4abd-b73e-7c4f93cfadeb-0', usage_metadata={'input_tokens': 2922, 'output_tokens': 30, 'total_tokens': 2952, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='엔젤공방거리 조성 사업에 지원하려면 다음의 서류를 제출해야 합니다:\n\n1. **사업계획서**: 지원하고자 하는 사업의 계획을 상세히 기술한 문서입니다.\n2. **구비서류**: 신청자가 요구하는 추가 서류로, 구체적인 내용은 강동구청 사회적경제과에 문의하여 확인해야 합니다.\n\n신청 절차에 대한 자세한 내용은 강동구청 홈페이지에서 확인할 수 있으며, 궁금한 사항은 강동구청 사회적경제과(전화: 02-3425-5822)로 문의하면 됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 137, 'prompt_tokens': 3265, 'total_tokens': 3402, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-7b4541a9-cb15-41f9-bc11-a13bbc09246d-0', usage_metadata={'input_tokens': 3265, 'output_tokens': 137, 'total_tokens': 3402, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='장기복무제대군인 무료법률구조지원의 주관 기관은 **국가보훈부**입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 3241, 'total_tokens': 3270, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-1e6aef9a-e0e1-46eb-8803-90d519efc117-0', usage_metadata={'input_tokens': 3241, 'output_tokens': 29, 'total_tokens': 3270, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='장기복무제대군인 무료법률구조지원의 지원 대상 소송사건은 다음과 같습니다:\n\n1. 민사사건\n2. 가사사건\n3. 행정심판사건\n4. 행정소송사건\n5. 헌법소원사건\n6. 형사사건\n7. 국가배상법에 따른 손해배상사건\n\n단, 국가를 당사자로 하는 소송에 대해서는 지원되지 않으며, 법률에 따라 국가를 당사자 또는 참가인으로 하는 국가소송도 제외됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 130, 'prompt_tokens': 3791, 'total_tokens': 3921, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-7d43fa19-548c-46e9-97bf-8d14066f35fd-0', usage_metadata={'input_tokens': 3791, 'output_tokens': 130, 'total_tokens': 3921, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='장기복무제대군인 무료법률구조지원을 신청하려면 인터넷을 통해 국가보훈부 홈페이지의 민원 섹션에서 신청할 수 있습니다. 또한, 방문이나 우편으로도 신청이 가능합니다. 신청을 위해 필요한 서류는 없으며, 담당 공무원이 중 장기복무제대군인 등록 여부와 군인연금 수급권 유무를 확인합니다. 자세한 문의는 법률구조공단 고객상담센터(전화: 132)를 통해 할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 115, 'prompt_tokens': 3242, 'total_tokens': 3357, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 3072}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-6282715e-0de9-43db-90ff-110a0c06cf00-0', usage_metadata={'input_tokens': 3242, 'output_tokens': 115, 'total_tokens': 3357, 'input_token_details': {'audio': 0, 'cache_read': 3072}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
# context 추가
eval_df["retrieved_contexts"] = context_list

# 정답 추가
eval_df["response"] = response_list

# csv 파일로 저장
output_path = 'finaaaaal_question.csv'
eval_df.to_csv(output_path, index=False, encoding='utf-8')

# 저장된 파일 확인
print(f"CSV 파일이 {output_path}에 저장되었습니다.")
# Out:
# CSV 파일이 finaaaaal_question.csv에 저장되었습니다.

# %% [markdown]
# ## 평가

# %%
# 위의 코드를 연속적으로 실행 중인 경우엔 해당 코드를 실행하지 않아도 됨.
## csv로 저장된 파일을 불러와서 평가를 진행할 경우에만 실행.

import pandas as pd
import ast

# CSV 파일 경로
csv_file_path = "finaaaaal_question.csv"

# CSV 파일 읽기
eval_df = pd.read_csv(csv_file_path)

### CSV 파일을 불러올 경우, 'retrieved_contexts' 항목이 문자열이기 때문에 올바른 데이터 유형인 LIST로 변경해주어야 함.
eval_df['retrieved_contexts'] = eval_df['retrieved_contexts'].apply(ast.literal_eval)

# Dataframe으로 부터 EvalDataset 생성
eval_dataset = EvaluationDataset.from_pandas(eval_df)
eval_dataset
# Out:
# EvaluationDataset(features=['user_input', 'retrieved_contexts', 'response', 'reference'], len=300)

# %%
model_name = "gpt-4o"
model = ChatOpenAI(model=model_name)
eval_llm = LangchainLLMWrapper(model)

embedding_model = OpenAIEmbeddings(model="text-embedding-3-large")
eval_embedding = LangchainEmbeddingsWrapper(embedding_model)

# %%
# 분당 토큰 리미트으로 평가별 나누어 실행
run_config = RunConfig(
    timeout=360,
    max_retries=20,
    max_wait=360,
    max_workers=1
)

metrics1 = [
    LLMContextRecall(llm=eval_llm),
]
metrics2 = [
    LLMContextPrecisionWithReference(llm=eval_llm),
]
metrics3 = [
    Faithfulness(llm=eval_llm),
]
metrics4 = [
    AnswerRelevancy(llm=eval_llm, embeddings=eval_embedding)
]

# %%
result1 = evaluate(dataset=eval_dataset, metrics=metrics1, run_config=run_config, batch_size=5)
result1

# %%
result2 = evaluate(dataset=eval_dataset, metrics=metrics2, run_config=run_config, batch_size=5)
result2

# %%
result3 = evaluate(dataset=eval_dataset, metrics=metrics3, run_config=run_config, batch_size=5)
result3

# %%
result4 = evaluate(dataset=eval_dataset, metrics=metrics4, run_config=run_config, batch_size=5)
result4
